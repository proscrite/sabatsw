# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#from jupyterthemes import jtplot

# %%
jtplot.style('default', grid = False)

# %%
filename = "C:\\Users\\Pablo\\Desktop\\SIMION\\quad_nobox_0_25grid\\output\\q_a_optimization.out"
def load_data(filename : str) -> pd.DataFrame:
    mass, a, q, trans = [], [], [], []
    with open(filename) as fin:
        lines = fin.readlines()
        for line, line2 in zip(lines[1:-1:7], lines[4:-1:7]):
            q.append(float(line.split(',')[2]))
            a.append(float(line.split(',')[1]))
            mass.append(int(line2.split(',')[0]))
            trans.append(float(line2.split(',')[3]))

    df = pd.DataFrame({'mass' : mass, 'q' : q, 'a' : a, 'transmission' : trans})
    return df

# %%
def plot_transmission_contours(dfm : pd.DataFrame, m : int = 0):
    """Contour plot transmission percentage on stability diagram.
    Parameters:
    dfm : pd.DataFrame
        Sub-dataframe for target mass
    m : int = 0
        Target mass. If unspecified, will be read out from dfm"""
    
    if m == 0: m = int(dfm.mass[0])
    X, Y = (dfm.a, dfm.q)
    Z = dfm.transmission
    fig, ax = plt.subplots()
    # ax.set_aspect('equal')
    tcf = ax.tricontourf(X, Y, Z)
    cb = fig.colorbar(tcf)
    cb.set_label('Transmission [%]')
    ax.set_title('Mass = %i amu' %m)
    ax.set_xlabel('$\\alpha$ [A. U.]')
    ax.set_ylabel('$q$ [A. U.]')

# %%
df = load_data(filename)
df134 = df.where(df.mass == 134).dropna()
df134
# Out:
#      mass      q      a  transmission
# 0   134.0  0.700  0.220     53.266332
# 1   134.0  0.705  0.220     44.845361
# 2   134.0  0.710  0.220     46.700508
# 3   134.0  0.715  0.220     51.500000
# 4   134.0  0.720  0.220     49.500000
# 5   134.0  0.700  0.225     32.160804
# 6   134.0  0.705  0.225     49.748744
# 7   134.0  0.710  0.225     53.000000
# 8   134.0  0.715  0.225     39.000000
# 9   134.0  0.720  0.225     54.639175
# 10  134.0  0.700  0.230      2.020202
# 11  134.0  0.705  0.230     11.675127
# 12  134.0  0.710  0.230     30.653266
# 13  134.0  0.715  0.230     17.500000
# 14  134.0  0.720  0.230     34.000000
# 15  134.0  0.700  0.235      0.000000
# 16  134.0  0.705  0.235      0.000000
# 17  134.0  0.710  0.235      4.000000
# 18  134.0  0.715  0.235      3.000000
# 19  134.0  0.720  0.235      0.000000
# 20  134.0  0.700  0.240      0.000000
# 21  134.0  0.705  0.240      0.000000
# 22  134.0  0.710  0.240      0.000000
# 23  134.0  0.715  0.240      0.000000
# 24  134.0  0.720  0.240      0.000000
# 25  134.0  0.700  0.245      0.000000
# 26  134.0  0.705  0.245      0.000000
# 27  134.0  0.710  0.245      0.000000
# 28  134.0  0.715  0.245      0.000000
# 29  134.0  0.720  0.245      0.000000
# 30  134.0  0.700  0.250      0.000000
# 31  134.0  0.705  0.250      0.000000
# 32  134.0  0.710  0.250      0.000000
# 33  134.0  0.715  0.250      0.000000
# 34  134.0  0.720  0.250      0.000000

# %%
plot_transmission_contours(df134)

# %%
masses = df.mass[~df.mass.duplicated()].values

for m in masses:
    dfm = df.where(df.mass == m).dropna()
    plot_transmission_contours(dfm, m)
