# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#from jupyterthemes import jtplot

# %%
jtplot.style('default', grid = False)

# %%
def load_data(filename : str) -> pd.DataFrame:
    mass, a, q, trans, ke, uke = [], [], [], [], [], []
    with open(filename) as fin:
        lines = fin.readlines()
        for line, line2 in zip(lines[1:-1:7], lines[4:-1:7]):
            q.append(float(line.split(',')[2]))
            a.append(float(line.split(',')[1]))
            voltage.append(int(line2.split(',')[0]))
            trans.append(float(line2.split(',')[3]))
            ke.append(float(line2.split(',')[4]))
            uke.append(float(line2.split(',')[5]))


    df = pd.DataFrame({'voltage' : voltage, 'q' : q, 'a' : a, 'transmission' : trans})
    return df

# %%
def plot_transmission_contours(dfm : pd.DataFrame, v : int = 0):
    """Contour plot transmission percentage on stability diagram.
    Parameters:
    dfm : pd.DataFrame
        Sub-dataframe for target ring voltage
    v : int = 0
        Target mass. If unspecified, will be read out from dfm"""
    
    if v == 0: v = int(dfm.voltage[0])
    X, Y = (dfm.a, dfm.q)
    Z = dfm.transmission
    fig, ax = plt.subplots()
    # ax.set_aspect('equal')
    tcf = ax.tricontourf(X, Y, Z)
    cb = fig.colorbar(tcf)
    cb.set_label('Transmission [%]')
    ax.set_xlabel('$\\alpha$ [A. U.]')
    ax.set_ylabel('$q$ [A. U.]')

# %% [markdown]
# # Run 1: outer ring = [10, 100, 200, 500, 1000, 1200]

# %%
filename = "C://Users//Pablo//Desktop//SIMION//quad_nobox_0_25grid//output/ring_voltages.out"

# %%
df = load_data(filename)
df134 = df.where(df.mass == 134).dropna()
df
# Out:
#     mass      q      a  transmission
# 0    -10  0.710  0.220     47.000000
# 1    -10  0.715  0.220     50.500000
# 2    -10  0.710  0.225     49.000000
# 3    -10  0.715  0.225     30.303030
# 4    100  0.710  0.220      0.000000
# 5    100  0.715  0.220      0.000000
# 6    100  0.710  0.225      0.000000
# 7    100  0.715  0.225      0.000000
# 8   -200  0.710  0.220     58.793970
# 9   -200  0.715  0.220     47.000000
# 10  -200  0.710  0.225     49.000000
# 11  -200  0.715  0.225     45.500000
# 12  -500  0.710  0.220     46.500000
# 13  -500  0.715  0.220     52.261307
# 14  -500  0.710  0.225     47.000000
# 15  -500  0.715  0.225     38.500000
# 16 -1000  0.710  0.220     48.484848
# 17 -1000  0.715  0.220     44.500000
# 18 -1000  0.710  0.225     43.500000
# 19 -1000  0.715  0.225     40.000000
# 20 -1200  0.710  0.220     47.000000
# 21 -1200  0.715  0.220     46.500000
# 22 -1200  0.710  0.225     53.000000
# 23 -1200  0.715  0.225     38.500000

# %%
masses
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8ce7fbfc6ea7> in <module>
# ----> 1 masses
#
# NameError: name 'masses' is not defined

# %%
masses = df.mass[~df.mass.duplicated()].values

for m in masses:
    dfm = df.where(df.mass == m).dropna()
    plot_transmission_contours(dfm, m)

# %% [markdown]
# # Run 2: masses [134:139]

# %%
filename = "C://Users//Pablo//Desktop//SIMION//quad_nobox_0_25grid//output/q_a_optimization2.out"
df = load_data(filename)

# %%
masses = df.mass[~df.mass.duplicated()].values

for m in masses:
    dfm = df.where(df.mass == m).dropna()
    plot_transmission_contours(dfm, m)

# %% [markdown]
# ##### Seems the predicted $\alpha$ range does not fully contain the maxima of transmission --> Extend range

# %% [markdown]
# # Run 3: masses [134:139], shifted alpha region

# %%
filename = "C://Users//Pablo//Desktop//SIMION//quad_nobox_0_25grid//output/q_a_optimization3.out"
df = load_data(filename)

# %%
masses = df.mass[~df.mass.duplicated()].values

for m in masses:
    dfm = df.where(df.mass == m).dropna()
    plot_transmission_contours(dfm, m)

# %% [markdown]
# # Run 3: masses [134:139], shifted alpha region

# %%
filename = "C://Users//Pablo//Desktop//SIMION//quad_nobox_0_25grid//output/q_a_optimization4.out"
df = load_data(filename)

# %%
masses = df.mass[~df.mass.duplicated()].values

for m in masses:
    dfm = df.where(df.mass == m).dropna()
    plot_transmission_contours(dfm, m)
