# %%
import sys
sys.path.append('C:\\Users\\IFIc\\Projects\\sabatsw\\laserlab\\scripts')
import matplotlib.pyplot as plt
from skimage import io

from galvo_python.galvos import *
from galvo_python.gaussian2dFit import *

# %%
serialport = open_serial_port(port_name="COM4")
# Out:
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# <ipython-input-186-bd7b584c6cae> in <module>
# ----> 1 serialport = open_serial_port(port_name="COM4")
#
# ~\Projects\sabatsw\laserlab\scripts\galvo_python\galvos.py in open_serial_port(port_name, baudrate)
#       2
#       3 def open_serial_port(port_name='COM4',  baudrate=115200):
# ----> 4     s = serial.Serial(port_name, baudrate=baudrate)
#       5     return s
#       6
#
# ~\Anaconda3\lib\site-packages\serial\serialwin32.py in __init__(self, *args, **kwargs)
#      29         self._overlapped_read = None
#      30         self._overlapped_write = None
# ---> 31         super(Serial, self).__init__(*args, **kwargs)
#      32
#      33     def open(self):
#
# ~\Anaconda3\lib\site-packages\serial\serialutil.py in __init__(self, port, baudrate, bytesize, parity, stopbits, timeout, xonxoff, rtscts, write_timeout, dsrdtr, inter_byte_timeout, exclusive, **kwargs)
#     238
#     239         if port is not None:
# --> 240             self.open()
#     241
#     242     #  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
#
# ~\Anaconda3\lib\site-packages\serial\serialwin32.py in open(self)
#      60         if self._port_handle == win32.INVALID_HANDLE_VALUE:
#      61             self._port_handle = None    # 'cause __del__ is called anyway
# ---> 62             raise SerialException("could not open port {!r}: {!r}".format(self.portstr, ctypes.WinError()))
#      63
#      64         try:
#
# SerialException: could not open port 'COM4': PermissionError(13, 'Access is denied.', None, 5)

# %% [markdown]
# ## Initialize and configure cam0

# %%
import pylablib.aux_libs.devices.DCAM as cam
from pylablib.aux_libs.devices.DCAM_lib import lib, DCAMLibError

from time import sleep

# %%
#cam.restart_lib()   #  Run if driver is not recognized

# %%
cam.get_cameras_number()

cam.DCAMCamera(0).get_model_data()
# Out:
# ModelData(vendor='Hamamatsu', model='C13440-20C', serial_number='S/N: 303065', camera_version='4.31.B')

# %%
cam0 = cam.DCAMCamera(0)
lib.dcamapi_uninit()     # For some reason this must be run before opening the camera
cam0.open()

min_texp = cam0.properties['EXPOSURE TIME'].min
cam0.set_value('EXPOSURE TIME', min_texp)
# Out:
# 0.0010036691729323308

# %%
cam0.properties['EXPOSURE TIME']
# Out:
# Property(name='b'EXPOSURE TIME'', id=2031888, min=0.0010036691729323308, max=10.0, unit=1)

# %%
cam0.properties['EXPOSURE TIME'].get_value()
# Out:
# 0.0010036691729323308

# %%
cam0.properties
# Out:
# {'SENSOR MODE': Property(name='b'SENSOR MODE'', id=4194832, min=1.0, max=16.0, unit=0),
#  'READOUT SPEED': Property(name='b'READOUT SPEED'', id=4194576, min=1.0, max=2.0, unit=0),
#  'READOUT DIRECTION': Property(name='b'READOUT DIRECTION'', id=4194608, min=5.0, max=5.0, unit=0),
#  'COLORTYPE': Property(name='b'COLORTYPE'', id=4325664, min=1.0, max=1.0, unit=0),
#  'BIT PER CHANNEL': Property(name='b'BIT PER CHANNEL'', id=4325680, min=12.0, max=16.0, unit=0),
#  'TRIGGER SOURCE': Property(name='b'TRIGGER SOURCE'', id=1048848, min=1.0, max=4.0, unit=0),
#  'TRIGGER MODE': Property(name='b'TRIGGER MODE'', id=1049104, min=1.0, max=6.0, unit=0),
#  'TRIGGER ACTIVE': Property(name='b'TRIGGER ACTIVE'', id=1048864, min=1.0, max=3.0, unit=0),
#  'TRIGGER GLOBAL EXPOSURE': Property(name='b'TRIGGER GLOBAL EXPOSURE'', id=2032384, min=3.0, max=5.0, unit=0),
#  'TRIGGER POLARITY': Property(name='b'TRIGGER POLARITY'', id=1049120, min=1.0, max=2.0, unit=0),
#  'TRIGGER CONNECTOR': Property(name='b'TRIGGER CONNECTOR'', id=1049136, min=1.0, max=2.0, unit=0),
#  'TRIGGER TIMES': Property(name='b'TRIGGER TIMES'', id=1049152, min=1.0, max=10000.0, unit=0),
#  'TRIGGER DELAY': Property(name='b'TRIGGER DELAY'', id=1049184, min=0.0, max=10.0, unit=1),
#  'INTERNAL TRIGGER HANDLING': Property(name='b'INTERNAL TRIGGER HANDLING'', id=1049200, min=1.0, max=1.0, unit=0),
#  'SENSOR TEMPERATURE': Property(name='b'SENSOR TEMPERATURE'', id=2097936, min=-50.0, max=100.0, unit=2),
#  'SENSOR COOLER STATUS': Property(name='b'SENSOR COOLER STATUS'', id=2097984, min=1.0, max=3.0, unit=0),
#  'EXPOSURE TIME': Property(name='b'EXPOSURE TIME'', id=2031888, min=0.0010036691729323308, max=10.0, unit=1),
#  'DEFECT CORRECT MODE': Property(name='b'DEFECT CORRECT MODE'', id=4653072, min=1.0, max=2.0, unit=0),
#  'HOT PIXEL CORRECT LEVEL': Property(name='b'HOT PIXEL CORRECT LEVEL'', id=4653104, min=1.0, max=3.0, unit=0),
#  'BINNING': Property(name='b'BINNING'', id=4198672, min=1.0, max=4.0, unit=0),
#  'SUBARRAY HPOS': Property(name='b'SUBARRAY HPOS'', id=4202768, min=0.0, max=2044.0, unit=0),
#  'SUBARRAY HSIZE': Property(name='b'SUBARRAY HSIZE'', id=4202784, min=4.0, max=2048.0, unit=0),
#  'SUBARRAY VPOS': Property(name='b'SUBARRAY VPOS'', id=4202800, min=0.0, max=2044.0, unit=0),
#  'SUBARRAY VSIZE': Property(name='b'SUBARRAY VSIZE'', id=4202816, min=4.0, max=2048.0, unit=0),
#  'SUBARRAY MODE': Property(name='b'SUBARRAY MODE'', id=4202832, min=1.0, max=2.0, unit=0),
#  'INTENSITY LUT MODE': Property(name='b'INTENSITY LUT MODE'', id=3671312, min=1.0, max=2.0, unit=0),
#  'INTENSITY LUT PAGE': Property(name='b'INTENSITY LUT PAGE'', id=3671328, min=1.0, max=1.0, unit=0),
#  'EXTRACTION MODE': Property(name='b'EXTRACTION MODE'', id=4195872, min=1.0, max=1.0, unit=0),
#  'TIMING READOUT TIME': Property(name='b'TIMING READOUT TIME'', id=4206608, min=0.0, max=0.0, unit=1),
#  'TIMING CYCLIC TRIGGER PERIOD': Property(name='b'TIMING CYCLIC TRIGGER PERIOD'', id=4206624, min=0.0, max=0.0, unit=1),
#  'TIMING MIN TRIGGER BLANKING': Property(name='b'TIMING MIN TRIGGER BLANKING'', id=4206640, min=0.0, max=0.0, unit=1),
#  'TIMING MIN TRIGGER INTERVAL': Property(name='b'TIMING MIN TRIGGER INTERVAL'', id=4206672, min=0.0, max=0.0, unit=1),
#  'TIMING GLOBAL EXPOSURE DELAY': Property(name='b'TIMING GLOBAL EXPOSURE DELAY'', id=4206736, min=0.0, max=0.1099977142857143, unit=1),
#  'TIMING EXPOSURE': Property(name='b'TIMING EXPOSURE'', id=4206688, min=3.0, max=3.0, unit=0),
#  'TIMING INVALID EXPOSURE PERIOD': Property(name='b'TIMING INVALID EXPOSURE PERIOD'', id=4206704, min=0.0, max=0.1, unit=1),
#  'INTERNAL FRAME RATE': Property(name='b'INTERNAL FRAME RATE'', id=4208656, min=0.1, max=100.02286236854138, unit=5),
#  'INTERNAL FRAME INTERVAL': Property(name='b'INTERNAL FRAME INTERVAL'', id=4208672, min=0.009997714285714285, max=10.0, unit=1),
#  'INTERNAL LINE SPEED': Property(name='b'INTERNAL LINE SPEED'', id=4208704, min=0.6670524691358024, max=0.6670524691358024, unit=4),
#  'INTERNAL LINE INTERVAL': Property(name='b'INTERNAL LINE INTERVAL'', id=4208720, min=9.74436090225564e-06, max=9.74436090225564e-06, unit=1),
#  'IMAGE WIDTH': Property(name='b'IMAGE WIDTH'', id=4325904, min=1.0, max=2048.0, unit=0),
#  'IMAGE HEIGHT': Property(name='b'IMAGE HEIGHT'', id=4325920, min=1.0, max=2048.0, unit=0),
#  'IMAGE ROWBYTES': Property(name='b'IMAGE ROWBYTES'', id=4325936, min=2.0, max=4096.0, unit=0),
#  'IMAGE FRAMEBYTES': Property(name='b'IMAGE FRAMEBYTES'', id=4325952, min=2.0, max=8388608.0, unit=0),
#  'IMAGE TOP OFFSET BYTES': Property(name='b'IMAGE TOP OFFSET BYTES'', id=4325968, min=0.0, max=0.0, unit=0),
#  'IMAGE PIXEL TYPE': Property(name='b'IMAGE PIXEL TYPE'', id=4326000, min=1.0, max=3.0, unit=0),
#  'BUFFER ROWBYTES': Property(name='b'BUFFER ROWBYTES'', id=4326192, min=2.0, max=4096.0, unit=0),
#  'BUFFER FRAMEBYTES': Property(name='b'BUFFER FRAMEBYTES'', id=4326208, min=2.0, max=8388608.0, unit=0),
#  'BUFFER TOP OFFSET BYTES': Property(name='b'BUFFER TOP OFFSET BYTES'', id=4326224, min=0.0, max=8388608.0, unit=0),
#  'BUFFER PIXEL TYPE': Property(name='b'BUFFER PIXEL TYPE'', id=4326240, min=1.0, max=3.0, unit=0),
#  'RECORD FIXED BYTES PER FILE': Property(name='b'RECORD FIXED BYTES PER FILE'', id=4326416, min=256.0, max=256.0, unit=0),
#  'RECORD FIXED BYTES PER SESSION': Property(name='b'RECORD FIXED BYTES PER SESSION'', id=4326432, min=0.0, max=1088.0, unit=0),
#  'RECORD FIXED BYTES PER FRAME': Property(name='b'RECORD FIXED BYTES PER FRAME'', id=4326448, min=0.0, max=8388704.0, unit=0),
#  'NUMBER OF OUTPUT TRIGGER CONNECTOR': Property(name='b'NUMBER OF OUTPUT TRIGGER CONNECTOR'', id=1835024, min=3.0, max=3.0, unit=0),
#  'OUTPUT TRIGGER SOURCE[0]': Property(name='b'OUTPUT TRIGGER SOURCE[0]'', id=1835280, min=2.0, max=6.0, unit=0),
#  'OUTPUT TRIGGER POLARITY[0]': Property(name='b'OUTPUT TRIGGER POLARITY[0]'', id=1835296, min=1.0, max=2.0, unit=0),
#  'OUTPUT TRIGGER ACTIVE[0]': Property(name='b'OUTPUT TRIGGER ACTIVE[0]'', id=1835312, min=1.0, max=1.0, unit=0),
#  'OUTPUT TRIGGER DELAY[0]': Property(name='b'OUTPUT TRIGGER DELAY[0]'', id=1835328, min=0.0, max=10.0, unit=1),
#  'OUTPUT TRIGGER PERIOD[0]': Property(name='b'OUTPUT TRIGGER PERIOD[0]'', id=1835344, min=1e-06, max=10.0, unit=1),
#  'OUTPUT TRIGGER KIND[0]': Property(name='b'OUTPUT TRIGGER KIND[0]'', id=1835360, min=1.0, max=5.0, unit=0),
#  'OUTPUT TRIGGER BASE SENSOR[0]': Property(name='b'OUTPUT TRIGGER BASE SENSOR[0]'', id=1835376, min=1.0, max=16.0, unit=0),
#  'OUTPUT TRIGGER PRE HSYNC COUNT': Property(name='b'OUTPUT TRIGGER PRE HSYNC COUNT'', id=1835408, min=0.0, max=2047.0, unit=0),
#  'MASTER PULSE MODE': Property(name='b'MASTER PULSE MODE'', id=1966112, min=1.0, max=3.0, unit=0),
#  'MASTER PULSE TRIGGER SOURCE': Property(name='b'MASTER PULSE TRIGGER SOURCE'', id=1966128, min=1.0, max=2.0, unit=0),
#  'MASTER PULSE INTERVAL': Property(name='b'MASTER PULSE INTERVAL'', id=1966144, min=9.999999999999999e-06, max=10.0, unit=1),
#  'MASTER PULSE BURST TIMES': Property(name='b'MASTER PULSE BURST TIMES'', id=1966160, min=1.0, max=10000.0, unit=0),
#  'SYSTEM ALIVE': Property(name='b'SYSTEM ALIVE'', id=16711696, min=1.0, max=2.0, unit=0),
#  'CONVERSION FACTOR COEFF': Property(name='b'CONVERSION FACTOR COEFF'', id=16769040, min=0.0, max=255.99, unit=0),
#  'CONVERSION FACTOR OFFSET': Property(name='b'CONVERSION FACTOR OFFSET'', id=16769056, min=-65535.0, max=65535.0, unit=0),
#  'NUMBER OF VIEW': Property(name='b'NUMBER OF VIEW'', id=4325824, min=1.0, max=2.0, unit=0),
#  'IMAGE DETECTOR PIXEL WIDTH': Property(name='b'IMAGE DETECTOR PIXEL WIDTH'', id=4327440, min=6.5, max=6.5, unit=7),
#  'IMAGE DETECTOR PIXEL HEIGHT': Property(name='b'IMAGE DETECTOR PIXEL HEIGHT'', id=4327456, min=6.5, max=6.5, unit=7),
#  'IMAGE DETECTOR PIXEL NUM HORZ': Property(name='b'IMAGE DETECTOR PIXEL NUM HORZ'', id=4327472, min=2048.0, max=2048.0, unit=0),
#  'IMAGE DETECTOR PIXEL NUM VERT': Property(name='b'IMAGE DETECTOR PIXEL NUM VERT'', id=4327488, min=2048.0, max=2048.0, unit=0),
#  'TIME STAMP PRODUCER': Property(name='b'TIME STAMP PRODUCER'', id=4262416, min=2.0, max=5.0, unit=0),
#  'FRAME STAMP PRODUCER': Property(name='b'FRAME STAMP PRODUCER'', id=4262432, min=2.0, max=5.0, unit=0)}

# %%
cam0.start_acquisition()
cam0.get_status()
# Out:
# 'busy'

# %%
cam0.stop_acquisition()

# %% [markdown]
# ## Align laser after galvo

# %%
center0 = [int(65534./2)-3780,int(65534./2)+8900]#calibrated on 19/02/2020
move_to_positionXY(serialport, [0,0], center=center0)

# %%
center0 = [int(65534./2) + 3200, int(65534./2) +  7900] #calibrated on 13/05/2020
move_to_positionXY(serialport, [0,0], center=center0)

# %% [markdown]
# # Take snap of laser after galvo and before lenses

# %% [markdown]
# ## At d = 20 cm from galvo

# %% [markdown]
# ### Move laser to center of DCAM

# %%
move_to_positionXY(serialport, [250,0], center=center0)

# %% [markdown]
# ##### Old (had to recalibrate)

# %%
# %matplotlib inline

frame = cam0.get_frame(100)

gray = plt.imshow(frame)
plt.colorbar(gray)

# %%
move_to_positionXY(serialport, [0,100], center=center0)

# %%
plt.imsave('./aligning_4f_052020/test.tiff', frame)

# %%
frame = plt.imread('./aligning_4f_052020/test.tiff')
plt.imshow(frame)

# %%
guess_centroid(frame)
# Out:
# (735, 645)

# %%
img
# Out:
# array([1112.4638, 1143.2872, 1153.4647, ...,  807.6984,  784.3217,
#         779.3713])

# %%
img = rgb2gray(frame)
mx = guess_centroid(frame)
bounds = bound_roi(frame, mx, 500)
print(mx, bounds)
imroi = select_roi(frame, bounds)
gray = plt.imshow(imroi)
plt.colorbar(gray)
# Out:
# (589, 823) [89, 1089, 323, 1323]

# %%
frame2.shape, frame.shape
# Out:
# ((2048, 2048, 4), (2048, 2048, 4))

# %%
#plt.imsave('nolens_20cm.tiff', frame)

# %%
plt.imsave('./aligning_4f_052020/nolens_20cm.tiff', frame)

# %% [markdown]
# ## Fit double gaussian

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ##  At d = 3 cm from galvo

# %% [markdown]
# ### Move laser to center of DCAM

# %%
move_to_positionXY(serialport, [0,3000], center=center0)
frame2 = cam0.get_frame(100)

gray2 = plt.imshow(frame2)
plt.colorbar(gray2)

# %%
plt.style.use('default')

# %%
move_to_positionXY(serialport, [200,4000], center=center0)
sleep(1)
# %matplotlib inline

frame = cam0.get_frame(100)

gray = plt.imshow(frame)
plt.colorbar(gray)

mx = guess_centroid(frame0)
bounds = bound_roi(frame0, mx, size = 100)
imroi = select_roi(frame0, bounds)
mxroi = guess_centroid(imroi)
img = ax2.imshow(frame0)
fig.colorbar(img)

fitr, fitc = fitGausRowCol(imroi, mxroi, flag_p=False)

# %%
# %matplotlib inline

frame0 = cam0.get_frame(100)

gray = plt.imshow(frame0)
plt.colorbar(gray)

mx = guess_centroid(frame0)
bounds = bound_roi(frame0, mx, size = 100)
imroi = select_roi(frame0, bounds)
mxroi = guess_centroid(imroi)
img = ax2.imshow(frame0)
fig.colorbar(img)

fitr, fitc = fitGausRowCol(imroi, mxroi, flag_p=False)

# %%
plt.imsave('nolens_3cm.tiff', frame0, )

# %%
from skimage import io
io.imsave("nolens_3cm.tiff", frame0)

# %%
framer = plt.imread('nolens_3cm.tiff')
img = plt.imshow(framer)
fig.colorbar(img)

# %%
np.max(framer)
# Out:
# 45221

# %%
frame0
# Out:
# array([[109, 115, 117, ..., 127, 118, 113],
#        [115, 105, 120, ..., 124, 109, 126],
#        [116, 119, 114, ..., 123, 121, 121],
#        ...,
#        [112, 117, 110, ..., 118, 118, 117],
#        [104, 110, 100, ..., 119, 117, 108],
#        [106, 117, 117, ..., 114, 102, 111]], dtype=uint16)

# %%
framer
# Out:
# array([[109, 115, 117, ..., 127, 118, 113],
#        [115, 105, 120, ..., 124, 109, 126],
#        [116, 119, 114, ..., 123, 121, 121],
#        ...,
#        [112, 117, 110, ..., 118, 118, 117],
#        [104, 110, 100, ..., 119, 117, 108],
#        [106, 117, 117, ..., 114, 102, 111]], dtype=uint16)

# %%
frame0.shape
# Out:
# (2048, 2048)

# %%
framer.shape
# Out:
# (2048, 2048)

# %%
plt.imshow()

# %%
frame0 == framer
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])

# %%
fitr, fitc = fitGausRowCol(imroi, mxroi, flag_p=True)

# %%
plt.imsave('nolens_3cm.tiff', frame2)

# %%
frame2 = plt.imread('nolens_3cm.tiff')
plt.imshow(frame2)

bestfit2 = guessNfitGaussian2d(frame2)
plot_fit_result(frame2, bestfit2)
# Out:
# (934, 1137) [434, 1434, 637, 1637]

# %%
bestfit2 = guessNfitGaussian2d(frame)
plot_fit_result(frame2, bestfit2)
# Out:
# (812,) [312, 1312]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-91-37c37f974b00> in <module>
# ----> 1 bestfit2 = guessNfitGaussian2d(frame)
#       2 plot_fit_result(frame2, bestfit2)
#
# ~\Projects\sabatsw\laserlab\scripts\galvo_python\gaussian2dFit.py in guessNfitGaussian2d(im, DEBUG, flag_p)
#     134     bounds = bound_roi(img, mx, 500)
#     135     print(mx, bounds)
# --> 136     imroi = select_roi(img, bounds)
#     137
#     138     mxroi = guess_centroid(imroi)
#
# ~\Projects\sabatsw\laserlab\scripts\galvo_python\gaussian2dFit.py in select_roi(im, bounds)
#      27
#      28 def select_roi(im : np.ndarray, bounds : list) -> np.ndarray:
# ---> 29     return im[bounds[0] : bounds[1], bounds[2] : bounds[3]]
#      30
#      31 def plot_fit_result(im : np.ndarray, p0 : list, ax = None):
#
# IndexError: list index out of range

# %% [markdown]
# # At d = 160 cm from galvo

# %% [markdown]
# ### Move laser to center of DCAM

# %%
move_to_positionXY(serialport, [200,0], center=center0)

# %%
frame0 = cam0.get_frame(100)

gray = plt.imshow(frame0)
plt.colorbar(gray)

# %%
frame0 = cam0.get_frame(100)

gray = plt.imshow(frame0)
plt.colorbar(gray)

# %%
plt.imsave('./aligning_4f_052020/nolens_160cm.tiff', frame0)

# %%
frame0 = plt.imread('./aligning_4f_052020/nolens_160cm.tiff')

# %%
bestfit1 = guessNfitGaussian2d(frame0, flag_p=False)

plot_fit_result(frame0, bestfit1)
# Out:
# (1330, 1195) [830, 1830, 695, 1695]

# %%
frame2 = plt.imread('nolens_3cm.tiff')
plt.imshow(frame2)

bestfit2 = guessNfitGaussian2d(frame2)
plot_fit_result(frame2, bestfit2)
# Out:
# (934, 1137) [434, 1434, 637, 1637]

# %% [markdown]
# ##### Okay, not too bad collimation: 62 px in x and 400 px in y

# %% [markdown]
# # Set lens 2 at d = 80 cm from galvo

# %%
move_to_positionXY(serialport, [-50,200], center=center0)

# %%
# %matplotlib notebook
frame0 = cam0.get_frame(100)
fig, ax = plt.subplots (1, 2, figsize=(15,15))
gray = ax[0].imshow(frame0)
#bestfit2 = guessNfitGaussian2d(frame0, DEBUG=True)
#plot_fit_result(frame0, bestfit2)
mx = guess_centroid(frame0)
bounds = bound_roi(frame0, mx, size = 100)
imroi = select_roi(frame0, bounds)
mxroi = guess_centroid(imroi)
ax[1].imshow(imroi)

fitr, fitc = fitGausRowCol(imroi, mxroi, flag_p=False)
sigma_x = fitc[2]
sigma_y = fitr[2]
p0 = [imroi.max(), mxroi[1], mxroi[0], sigma_x, sigma_y]

fit = fitGauss2d(imroi, p0 = p0)
pars = make_params(fit);
plot_fit_result(imroi, pars)
plt.legend()
plt.colorbar(gray)

# %%
def fitGausRowCol(im : np.ndarray, mx : tuple, flag_p : bool = False, ax = None):
    """Fit a gaussian on the (row, column) of im specified by mx
    Can be used to guess sigma_x and sigma_y"""

    from peakutils import baseline
    bl = np.average(baseline(im[mx[0], :]))
    from scipy.optimize import curve_fit
    yrow = im[mx[0], :]
    xrow = range(len(yrow))
    prow0 = [yrow.max(), np.argmax(yrow), 10, bl]
    fitrow, _ = curve_fit(gauss, xrow, yrow, p0 = prow0)

    ycol = im.T[mx[1], :]
    xcol = range(len(ycol))
    pcol0 = [ycol.max(), np.argmax(ycol), 10, bl]
    fitcol, _ = curve_fit(gauss, xcol, ycol, p0=pcol0)
    if flag_p: plotProfiles(yrow, ycol, fitrow, fitcol, ax=ax)
    return fitcol, fitrow

def plotProfiles(yrow, ycol, fitr, fitc, ax=None):
    
    #fig, ax = plt.subplots(1, 2, figsize=(16,8))
    ax[0].plot(ycol)
    xpl = range(len(ycol))
    ax[0].plot(gauss(xpl, *fitc), label = '$\sigma = $ %.1f' %fitc[2])
    ax[0].set_title("X profile")
    ax[0].legend(fontsize=12)

    ax[1].plot(yrow)
    xpl2 = range(len(yrow))
    ax[1].plot(gauss(xpl2, *fitr), label = '$\sigma = $ %.1f' %fitr[2])
    ax[1].set_title("Y profile")
    ax[1].legend(fontsize=12)

# %%
# %matplotlib notebook
#fig, ax = plt.subplots(2, figsize=(12,12))
fig = plt.figure(figsize=(10,10))
fig.show()
fig.canvas.draw()
plt.style.use('dark_background')
sx, sy = [], []
while True:
    fig = plt.gcf()
    ax1 = fig.add_subplot(1, 1, 1)
    
    frame0 = cam0.get_frame(100)

    img = ax1.imshow(frame0)
    fig.colorbar(img)
    
    fig.canvas.draw()
    fig.tight_layout()
    #fig.canvas.update()
    fig.canvas.flush_events()
    plt.clf()
# Out:
# <img src="data:image/png;base64,..." width="720">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-125-a3ed00391854> in <module>
#      15     fig.colorbar(img)
#      16
# ---> 17     fig.canvas.draw()
#      18     fig.tight_layout()
#      19     #fig.canvas.update()
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_webagg_core.py in draw(self)
#     149         self._png_is_old = True
#     150         try:
# --> 151             super().draw()
#     152         finally:
#     153             self.manager.refresh_all()  # Swap the frames.
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in draw(self, renderer, *args, **kwargs)
#     617         else:
#     618             im, l, b, trans = self.make_image(
# --> 619                 renderer, renderer.get_image_magnification())
#     620             if im is not None:
#     621                 renderer.draw_image(gc, l, b, im)
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in make_image(self, renderer, magnification, unsampled)
#     879         return self._make_image(
#     880             self._A, bbox, transformed_bbox, self.axes.bbox, magnification,
# --> 881             unsampled=unsampled)
#     882
#     883     def _check_unsampled_image(self, renderer):
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     475                 # will be between [0, 1] (such as a rotated image).
#     476
# --> 477                 out_alpha = np.array(out_mask)
#     478                 out_mask = np.isnan(out_mask)
#     479                 out_alpha[out_mask] = 1
#
# KeyboardInterrupt:
# <img src="data:image/png;base64,..." width="720">

# %%
# %matplotlib notebook
#fig, ax = plt.subplots(2, figsize=(12,12))
fig = plt.figure(figsize=(10,10))
fig.show()
fig.canvas.draw()
plt.style.use('dark_background')
sx, sy = [], []
while True:
    fig = plt.gcf()
    ax1 = fig.add_subplot(3, 1, 1)

    frame0 = cam0.get_frame(100)

    img = ax1.imshow(frame0)
    fig.colorbar(img)
    
    mx = guess_centroid(frame0)
    bounds = bound_roi(frame0, mx, size = 100)
    imroi = select_roi(frame0, bounds)
    mxroi = guess_centroid(imroi)

    fitr, fitc = fitGausRowCol(imroi, mxroi, flag_p=False)
    
    fig.canvas.draw()
    fig.tight_layout()
    #fig.canvas.update()
    fig.canvas.flush_events()
    plt.clf()
# Out:
# <img src="data:image/png;base64,..." width="720">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-207-a7a44761fdd7> in <module>
#      22     fitr, fitc = fitGausRowCol(imroi, mxroi, flag_p=False)
#      23
# ---> 24     fig.canvas.draw()
#      25     fig.tight_layout()
#      26     #fig.canvas.update()
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_webagg_core.py in draw(self)
#     149         self._png_is_old = True
#     150         try:
# --> 151             super().draw()
#     152         finally:
#     153             self.manager.refresh_all()  # Swap the frames.
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1201         renderer.open_group(__name__)
#    1202
# -> 1203         ticks_to_draw = self._update_ticks()
#    1204         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1205                                                                 renderer)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1079         major_locs = self.get_majorticklocs()
#    1080         major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1081         major_ticks = self.get_major_ticks(len(major_locs))
#    1082         self.major.formatter.set_locs(major_locs)
#    1083         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1412             self.majorTicks.append(tick)
#    1413             tick.gridline.set_visible(self._gridOnMajor)
# -> 1414             self._copy_tick_props(self.majorTicks[0], tick)
#    1415
#    1416         return self.majorTicks[:numticks]
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _copy_tick_props(self, src, dest)
#    1378         dest.label1.update_from(src.label1)
#    1379         dest.label2.update_from(src.label2)
# -> 1380         dest.tick1line.update_from(src.tick1line)
#    1381         dest.tick2line.update_from(src.tick2line)
#    1382         dest.gridline.update_from(src.gridline)
#
# ~\Anaconda3\lib\site-packages\matplotlib\lines.py in update_from(self, other)
#    1347         self._linestyle = other._linestyle
#    1348         self._marker = MarkerStyle(other._marker.get_marker(),
# -> 1349                                    other._marker.get_fillstyle())
#    1350         self._drawstyle = other._drawstyle
#    1351
#
# ~\Anaconda3\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     241         self._marker_function = None
#     242         self.set_fillstyle(fillstyle)
# --> 243         self.set_marker(marker)
#     244
#     245     def _recache(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     314
#     315         self._marker = marker
# --> 316         self._recache()
#     317
#     318     def get_path(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\markers.py in _recache(self)
#     254         self._capstyle = 'butt'
#     255         self._filled = True
# --> 256         self._marker_function()
#     257
#     258     def __bool__(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\markers.py in _set_tickleft(self)
#     747
#     748     def _set_tickleft(self):
# --> 749         self._transform = Affine2D().scale(-1.0, 1.0)
#     750         self._snap_threshold = 1.0
#     751         self._filled = False
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in __init__(self, matrix, **kwargs)
#    1830         if matrix is None:
#    1831             # A bit faster than np.identity(3).
# -> 1832             matrix = IdentityTransform._mtx.copy()
#    1833         self._mtx = matrix
#    1834         self._invalid = 0
#
# KeyboardInterrupt:
# <img src="data:image/png;base64,..." width="720">

# %%
# %matplotlib notebook
#fig, ax = plt.subplots(2, figsize=(12,12))
fig = plt.figure(figsize=(10,10))
fig.show()
fig.canvas.draw()
plt.style.use('dark_background')
sx, sy = [], []
while True:
    
    fig = plt.gcf()
    ax1 = fig.add_subplot(3, 1, 1)
    ax2 = fig.add_subplot(3, 1, 2)
    ax3 = fig.add_subplot(3, 1, 3)


    frame0 = cam0.get_frame(100)

    #gray = ax[0].imshow(frame0)
    #plt.colorbar(gray)

    mx = guess_centroid(frame0)
    bounds = bound_roi(frame0, mx, size = 100)
    imroi = select_roi(frame0, bounds)
    mxroi = guess_centroid(imroi)
    img = ax2.imshow(frame0)
    fig.colorbar(img)

    fitr, fitc = fitGausRowCol(imroi, mxroi, flag_p=False)
    sigma_x = fitc[2]
    sigma_y = fitr[2]
    p0 = [imroi.max(), mxroi[1], mxroi[0], sigma_x, sigma_y]
    fit = fitGauss2d(imroi, p0 = p0)
    pars = make_params(fit);
    if (pars[3] > 0 ) and (pars[4] > 0):
        sx.append(pars[3])
        sy.append(pars[4])
    plot_fit_result(imroi, pars, ax=ax1)
    
    ax3.plot(sx, label='$\sigma_x$')
    ax3.plot(sy, label='$\sigma_y$')
    ax3.set_ylim(15, 25)
    ax3.legend()
    fig.canvas.draw()
    fig.tight_layout()
    #fig.canvas.update()
    fig.canvas.flush_events()
    fig.subplots_adjust(left=0.2, bottom=None, right=0.8, top=None, wspace=0.1, hspace=None)
    plt.clf()     # Clean figure to update legend, barplot...
# Out:
# <img src="data:image/png;base64,..." width="720">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-d168666ba094> in <module>
#      46     fig.canvas.flush_events()
#      47     fig.subplots_adjust(left=0.2, bottom=None, right=0.8, top=None, wspace=0.1, hspace=None)
# ---> 48     plt.clf()     # Clean figure to update legend, barplot...
#      49
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in clf()
#     696 def clf():
#     697     """Clear the current figure."""
# --> 698     gcf().clf()
#     699
#     700
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in clf(self, keep_observers)
#    1633
#    1634         for ax in tuple(self.axes):  # Iterate over the copy.
# -> 1635             ax.cla()
#    1636             self.delaxes(ax)         # removes ax from self._axstack
#    1637
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in cla(self)
#     971         yaxis_visible = self.yaxis.get_visible()
#     972
# --> 973         self.xaxis.cla()
#     974         self.yaxis.cla()
#     975
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in cla(self)
#     833                              rcParams['axes.grid.which'] in ('both', 'minor'))
#     834
# --> 835         self.reset_ticks()
#     836
#     837         self.converter = None
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in reset_ticks(self)
#     856             pass
#     857         try:
# --> 858             self.set_clip_path(self.axes.patch)
#     859         except AttributeError:
#     860             pass
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in set_clip_path(self, clippath, transform)
#     946         martist.Artist.set_clip_path(self, clippath, transform)
#     947         for child in self.majorTicks + self.minorTicks:
# --> 948             child.set_clip_path(clippath, transform)
#     949         self.stale = True
#     950
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in set_clip_path(self, clippath, transform)
#     230     def set_clip_path(self, clippath, transform=None):
#     231         # docstring inherited
# --> 232         martist.Artist.set_clip_path(self, clippath, transform)
#     233         self.gridline.set_clip_path(clippath, transform)
#     234         self.stale = True
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in set_clip_path(self, path, transform)
#     730             if isinstance(path, Rectangle):
#     731                 self.clipbox = TransformedBbox(Bbox.unit(),
# --> 732                                                path.get_transform())
#     733                 self._clippath = None
#     734                 success = True
#
# ~\Anaconda3\lib\site-packages\matplotlib\patches.py in get_transform(self)
#     212         to the :class:`Patch`.
#     213         """
# --> 214         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     215
#     216     def get_data_transform(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\patches.py in get_patch_transform(self)
#     756
#     757     def get_patch_transform(self):
# --> 758         self._update_patch_transform()
#     759         return self._rect_transform
#     760
#
# ~\Anaconda3\lib\site-packages\matplotlib\patches.py in _update_patch_transform(self)
#     734         x0, y0, x1, y1 = self._convert_units()
#     735         bbox = transforms.Bbox.from_extents(x0, y0, x1, y1)
# --> 736         rot_trans = transforms.Affine2D()
#     737         rot_trans.rotate_deg_around(x0, y0, self.angle)
#     738         self._rect_transform = transforms.BboxTransformTo(bbox)
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in __init__(self, matrix, **kwargs)
#    1830         if matrix is None:
#    1831             # A bit faster than np.identity(3).
# -> 1832             matrix = IdentityTransform._mtx.copy()
#    1833         self._mtx = matrix
#    1834         self._invalid = 0
#
# KeyboardInterrupt:
# <img src="data:image/png;base64,..." width="720">

# %% [markdown]
# ## Fine tuning position

# %%
# %matplotlib notebook
#fig, ax = plt.subplots(2, figsize=(12,12))
fig = plt.figure(figsize=(10,10))
fig.show()
fig.canvas.draw()
plt.style.use('dark_background')
sx, sy = [], []
while True:
    
    fig = plt.gcf()
    ax1 = fig.add_subplot(3, 1, 1)
    ax2 = fig.add_subplot(3, 1, 2)
    ax3 = fig.add_subplot(3, 1, 3)


    frame0 = cam0.get_frame(100)

    #gray = ax[0].imshow(frame0)
    #plt.colorbar(gray)

    mx = guess_centroid(frame0)
    bounds = bound_roi(frame0, mx, size = 100)
    imroi = select_roi(frame0, bounds)
    mxroi = guess_centroid(imroi)
    img = ax2.imshow(frame0)
    fig.colorbar(img)

    fitr, fitc = fitGausRowCol(imroi, mxroi, flag_p=False)
    sigma_x = fitc[2]
    sigma_y = fitr[2]
    p0 = [imroi.max(), mxroi[1], mxroi[0], sigma_x, sigma_y]
    fit = fitGauss2d(imroi, p0 = p0)
    pars = make_params(fit);
    if (pars[3] > 0 ) and (pars[4] > 0):
        sx.append(pars[3])
        sy.append(pars[4])
    plot_fit_result(imroi, pars, ax=ax1)
    
    ax3.plot(sx, label='$\sigma_x$')
    ax3.plot(sy, label='$\sigma_y$')
    ax3.set_ylim(19.5, 22)
    ax3.legend()
    fig.canvas.draw()
    fig.tight_layout()
    #fig.canvas.update()
    fig.canvas.flush_events()
    fig.subplots_adjust(left=0.2, bottom=None, right=0.8, top=None, wspace=0.1, hspace=None)
    plt.clf()     # Clean figure to update legend, barplot...
# Out:
# <img src="data:image/png;base64,..." width="720">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-105-d2833d8a6b08> in <module>
#      30     sigma_y = fitr[2]
#      31     p0 = [imroi.max(), mxroi[1], mxroi[0], sigma_x, sigma_y]
# ---> 32     fit = fitGauss2d(imroi, p0 = p0)
#      33     pars = make_params(fit);
#      34     if (pars[3] > 0 ) and (pars[4] > 0):
#
# ~\Projects\sabatsw\laserlab\scripts\galvo_python\gaussian2dFit.py in fitGauss2d(im, p0)
#      72     initial.add("background",value=0)
#      73
# ---> 74     fit = minimize(residuals, initial, args=(xx, yy, im))#, method='cg')
#      75     return fit
#      76
#
# ~\Anaconda3\lib\site-packages\lmfit\minimizer.py in minimize(fcn, params, method, args, kws, iter_cb, scale_covar, nan_policy, reduce_fcn, calc_covar, **fit_kws)
#    2391                        nan_policy=nan_policy, reduce_fcn=reduce_fcn,
#    2392                        calc_covar=calc_covar, **fit_kws)
# -> 2393     return fitter.minimize(method=method)
#
# ~\Anaconda3\lib\site-packages\lmfit\minimizer.py in minimize(self, method, params, **kws)
#    2174                         val.lower().startswith(user_method)):
#    2175                     kwargs['method'] = val
# -> 2176         return function(**kwargs)
#    2177
#    2178
#
# ~\Anaconda3\lib\site-packages\lmfit\minimizer.py in leastsq(self, params, **kws)
#    1566
#    1567         try:
# -> 1568             lsout = scipy_leastsq(self.__residual, variables, **lskws)
#    1569         except AbortFitException:
#    1570             pass
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     394             maxfev = 200*(n + 1)
#     395         retval = _minpack._lmdif(func, x0, args, full_output, ftol, xtol,
# --> 396                                  gtol, maxfev, epsfcn, factor, diag)
#     397     else:
#     398         if col_deriv:
#
# ~\Anaconda3\lib\site-packages\lmfit\minimizer.py in __residual(self, fvars, apply_bounds_transformation)
#     528         self.result.nfev += 1
#     529
# --> 530         out = self.userfcn(params, *self.userargs, **self.userkws)
#     531
#     532         if callable(self.iter_cb):
#
# ~\Projects\sabatsw\laserlab\scripts\galvo_python\gaussian2dFit.py in residuals(p, x, y, z)
#      58         sigma_y = p["sigma_y"].value
#      59         offset = p["background"].value
# ---> 60         return (z - height*gaussian2D(x,y, cen_x, cen_y, sigma_x, sigma_y, offset))
#      61
#      62     # test data
#
# ~\Projects\sabatsw\laserlab\scripts\galvo_python\gaussian2dFit.py in gaussian2D(x, y, cen_x, cen_y, sig_x, sig_y, offset)
#      49
#      50     def gaussian2D(x, y, cen_x, cen_y, sig_x, sig_y, offset):
# ---> 51         return np.exp(-(((cen_x-x)/sig_x)**2 + ((cen_y-y)/sig_y)**2)/2.0) + offset
#      52
#      53     def residuals(p, x, y, z):
#
# KeyboardInterrupt:
# <img src="data:image/png;base64,..." width="720">

# %% [markdown]
# ##### So se set position of lens 2, z2 = 12.21  and  zcam = 4.87 mm

# %%
# Relative position for reference (coordinated movement): the actual distance is 35-ish cm + dist_f2
dist_f2 =  12.21 + 4.87
dist_f2
# Out:
# 17.080000000000002

# %% [markdown]
# # Set lens 1 at d = 40 cm from galvo, now cam and lens 2 move together

# %%
# %matplotlib notebook
#fig, ax = plt.subplots(2, figsize=(12,12))
fig = plt.figure(figsize=(10,10))
fig.show()
fig.canvas.draw()
plt.style.use('dark_background')
sx, sy = [], []
while True:
    
    fig = plt.gcf()
    ax1 = fig.add_subplot(3, 1, 1)
    ax2 = fig.add_subplot(3, 1, 2)
    ax3 = fig.add_subplot(3, 1, 3)


    frame0 = cam0.get_frame(100)

    #gray = ax[0].imshow(frame0)
    #plt.colorbar(gray)

    mx = guess_centroid(frame0)
    bounds = bound_roi(frame0, mx, size = 100)
    imroi = select_roi(frame0, bounds)
    mxroi = guess_centroid(imroi)
    img = ax2.imshow(frame0)
    fig.colorbar(img)

    fitr, fitc = fitGausRowCol(imroi, mxroi, flag_p=False)
    sigma_x = fitc[2]
    sigma_y = fitr[2]
    p0 = [imroi.max(), mxroi[1], mxroi[0], sigma_x, sigma_y]
    fit = fitGauss2d(imroi, p0 = p0)
    pars = make_params(fit);
    if (pars[3] > 0 ) and (pars[4] > 0):
        sx.append(pars[3])
        sy.append(pars[4])
    plot_fit_result(imroi, pars, ax=ax1)
    
    ax3.plot(sx, label='$\sigma_x$')
    ax3.plot(sy, label='$\sigma_y$')
#    ax3.set_ylim(15, 25)
    ax3.legend()
    fig.canvas.draw()
    fig.tight_layout()
    #fig.canvas.update()
    fig.canvas.flush_events()
    fig.subplots_adjust(left=0.2, bottom=None, right=0.8, top=None, wspace=0.1, hspace=None)
    plt.clf()     # Clean figure to update legend, barplot...
# Out:
# <img src="data:image/png;base64,..." width="NaN">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-124-3b6cc1b708ee> in <module>
#      41 #    ax3.set_ylim(15, 25)
#      42     ax3.legend()
# ---> 43     fig.canvas.draw()
#      44     fig.tight_layout()
#      45     #fig.canvas.update()
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_webagg_core.py in draw(self)
#     151             super().draw()
#     152         finally:
# --> 153             self.manager.refresh_all()  # Swap the frames.
#     154
#     155     def draw_idle(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_webagg_core.py in refresh_all(self)
#     444             if diff is not None:
#     445                 for s in self.web_sockets:
# --> 446                     s.send_binary(diff)
#     447
#     448     @classmethod
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_nbagg.py in send_binary(self, blob)
#     204         data = b64encode(blob).decode('ascii')
#     205         data_uri = "data:image/png;base64,{0}".format(data)
# --> 206         self.comm.send({'data': data_uri})
#     207
#     208     def on_message(self, message):
#
# ~\Anaconda3\lib\site-packages\ipykernel\comm\comm.py in send(self, data, metadata, buffers)
#     119         """Send a message to the frontend-side version of this comm"""
#     120         self._publish_msg('comm_msg',
# --> 121             data=data, metadata=metadata, buffers=buffers,
#     122         )
#     123
#
# ~\Anaconda3\lib\site-packages\ipykernel\comm\comm.py in _publish_msg(self, msg_type, data, metadata, buffers, **keys)
#      69             parent=self.kernel._parent_header,
#      70             ident=self.topic,
# ---> 71             buffers=buffers,
#      72         )
#      73
#
# ~\Anaconda3\lib\site-packages\jupyter_client\session.py in send(self, stream, msg_or_type, content, parent, ident, buffers, track, header, metadata)
#     735         if self.adapt_version:
#     736             msg = adapt(msg, self.adapt_version)
# --> 737         to_send = self.serialize(msg, ident)
#     738         to_send.extend(buffers)
#     739         longest = max([ len(s) for s in to_send ])
#
# ~\Anaconda3\lib\site-packages\jupyter_client\session.py in serialize(self, msg, ident)
#     648         to_send.append(DELIM)
#     649
# --> 650         signature = self.sign(real_message)
#     651         to_send.append(signature)
#     652
#
# ~\Anaconda3\lib\site-packages\jupyter_client\session.py in sign(self, msg_list)
#     593         h = self.auth.copy()
#     594         for m in msg_list:
# --> 595             h.update(m)
#     596         return str_to_bytes(h.hexdigest())
#     597
#
# ~\Anaconda3\lib\hmac.py in update(self, msg)
#     100         """Update this hashing object with the string msg.
#     101         """
# --> 102         self.inner.update(msg)
#     103
#     104     def copy(self):
#
# KeyboardInterrupt:

# %%
plt.gcf()
plt.savefig('./aligning_4f_052020\lens1_pos.png')

# %%
# %matplotlib notebook
#fig, ax = plt.subplots(2, figsize=(12,12))
fig = plt.figure(figsize=(10,10))
fig.show()
fig.canvas.draw()
plt.style.use('dark_background')
sx, sy = [], []
while True:
    
    fig = plt.gcf()
    ax1 = fig.add_subplot(3, 1, 1)
    ax2 = fig.add_subplot(3, 1, 2)
    ax3 = fig.add_subplot(3, 1, 3)


    frame0 = cam0.get_frame(100)

    #gray = ax[0].imshow(frame0)
    #plt.colorbar(gray)

    mx = guess_centroid(frame0)
    bounds = bound_roi(frame0, mx, size = 100)
    imroi = select_roi(frame0, bounds)
    mxroi = guess_centroid(imroi)
    img = ax2.imshow(frame0)
    fig.colorbar(img)

    fitr, fitc = fitGausRowCol(imroi, mxroi, flag_p=False)
    sigma_x = fitc[2]
    sigma_y = fitr[2]
    p0 = [imroi.max(), mxroi[1], mxroi[0], sigma_x, sigma_y]
    fit = fitGauss2d(imroi, p0 = p0)
    pars = make_params(fit);
    if (pars[3] > 0 ) and (pars[4] > 0):
        sx.append(pars[3])
        sy.append(pars[4])
    plot_fit_result(imroi, pars, ax=ax1)
    
    ax3.plot(sx, label='$\sigma_x$')
    ax3.plot(sy, label='$\sigma_y$')
    ax3.set_ylim(15, 25)
    ax3.legend()
    fig.canvas.draw()
    fig.tight_layout()
    #fig.canvas.update()
    fig.canvas.flush_events()
    fig.subplots_adjust(left=0.2, bottom=None, right=0.8, top=None, wspace=0.1, hspace=None)
    plt.clf()     # Clean figure to update legend, barplot...
# Out:
# <img src="data:image/png;base64,..." width="720">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-141-d168666ba094> in <module>
#      23     imroi = select_roi(frame0, bounds)
#      24     mxroi = guess_centroid(imroi)
# ---> 25     img = ax2.imshow(frame0)
#      26     fig.colorbar(img)
#      27
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5677             im.set_clim(vmin, vmax)
#    5678         else:
# -> 5679             im.autoscale_None()
#    5680         im.set_url(url)
#    5681
#
# ~\Anaconda3\lib\site-packages\matplotlib\cm.py in autoscale_None(self)
#     391         if self._A is None:
#     392             raise TypeError('You must first set_array for mappable')
# --> 393         self.norm.autoscale_None(self._A)
#     394         self.changed()
#     395
#
# ~\Anaconda3\lib\site-packages\matplotlib\colors.py in autoscale_None(self, A)
#    1001             self.vmin = A.min()
#    1002         if self.vmax is None and A.size:
# -> 1003             self.vmax = A.max()
#    1004
#    1005     def scaled(self):
#
# ~\Anaconda3\lib\site-packages\numpy\ma\core.py in max(self, axis, out, fill_value, keepdims)
#    5721         if out is None:
#    5722             result = self.filled(fill_value).max(
# -> 5723                 axis=axis, out=out, **kwargs).view(type(self))
#    5724             if result.ndim:
#    5725                 # Set the mask
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _amax(a, axis, out, keepdims, initial)
#      26 def _amax(a, axis=None, out=None, keepdims=False,
#      27           initial=_NoValue):
# ---> 28     return umr_maximum(a, axis, None, out, keepdims, initial)
#      29
#      30 def _amin(a, axis=None, out=None, keepdims=False,
#
# KeyboardInterrupt:

# %% [markdown]
# ##### Just moving lens 1 this is the minimum sigma I could get
